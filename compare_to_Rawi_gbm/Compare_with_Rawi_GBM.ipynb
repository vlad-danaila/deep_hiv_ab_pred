# %%
# !rm -vrf deep_hiv_ab_pred
# !git clone https://github.com/vlad-danaila/deep_hiv_ab_pred.git
# Out:
# removed directory 'deep_hiv_ab_pred/.git/branches'
# removed 'deep_hiv_ab_pred/.git/hooks/applypatch-msg.sample'
# removed 'deep_hiv_ab_pred/.git/hooks/commit-msg.sample'
# removed 'deep_hiv_ab_pred/.git/hooks/fsmonitor-watchman.sample'
# removed 'deep_hiv_ab_pred/.git/hooks/post-update.sample'
# removed 'deep_hiv_ab_pred/.git/hooks/pre-applypatch.sample'
# removed 'deep_hiv_ab_pred/.git/hooks/pre-commit.sample'
# removed 'deep_hiv_ab_pred/.git/hooks/pre-push.sample'
# removed 'deep_hiv_ab_pred/.git/hooks/pre-rebase.sample'
# removed 'deep_hiv_ab_pred/.git/hooks/pre-receive.sample'
# removed 'deep_hiv_ab_pred/.git/hooks/prepare-commit-msg.sample'
# removed 'deep_hiv_ab_pred/.git/hooks/update.sample'
# removed directory 'deep_hiv_ab_pred/.git/hooks'
# removed 'deep_hiv_ab_pred/.git/info/exclude'
# removed directory 'deep_hiv_ab_pred/.git/info'
# removed 'deep_hiv_ab_pred/.git/description'
# removed 'deep_hiv_ab_pred/.git/refs/heads/main'
# removed directory 'deep_hiv_ab_pred/.git/refs/heads'
# removed directory 'deep_hiv_ab_pred/.git/refs/tags'
# removed 'deep_hiv_ab_pred/.git/refs/remotes/origin/HEAD'
# removed directory 'deep_hiv_ab_pred/.git/refs/remotes/origin'
# removed directory 'deep_hiv_ab_pred/.git/refs/remotes'
# removed directory 'deep_hiv_ab_pred/.git/refs'
# removed 'deep_hiv_ab_pred/.git/HEAD'
# removed 'deep_hiv_ab_pred/.git/config'
# removed 'deep_hiv_ab_pred/.git/objects/pack/pack-0ec35fc99b2d7a1454df6560fd070fa668ea23f5.pack'
# removed 'deep_hiv_ab_pred/.git/objects/pack/pack-0ec35fc99b2d7a1454df6560fd070fa668ea23f5.idx'
# removed directory 'deep_hiv_ab_pred/.git/objects/pack'
# removed directory 'deep_hiv_ab_pred/.git/objects/info'
# removed directory 'deep_hiv_ab_pred/.git/objects'
# removed 'deep_hiv_ab_pred/.git/packed-refs'
# removed 'deep_hiv_ab_pred/.git/logs/refs/remotes/origin/HEAD'
# removed directory 'deep_hiv_ab_pred/.git/logs/refs/remotes/origin'
# removed directory 'deep_hiv_ab_pred/.git/logs/refs/remotes'
# removed 'deep_hiv_ab_pred/.git/logs/refs/heads/main'
# removed directory 'deep_hiv_ab_pred/.git/logs/refs/heads'
# removed directory 'deep_hiv_ab_pred/.git/logs/refs'
# removed 'deep_hiv_ab_pred/.git/logs/HEAD'
# removed directory 'deep_hiv_ab_pred/.git/logs'
# removed 'deep_hiv_ab_pred/.git/index'
# removed directory 'deep_hiv_ab_pred/.git'
# removed 'deep_hiv_ab_pred/.gitignore'
# removed 'deep_hiv_ab_pred/LICENSE'
# removed 'deep_hiv_ab_pred/README.md'
# removed 'deep_hiv_ab_pred/__init__.py'
# removed 'deep_hiv_ab_pred/catnap/__init__.py'
# removed 'deep_hiv_ab_pred/catnap/catnap_flat.json'
# removed 'deep_hiv_ab_pred/catnap/censored_data_preprocess.py'
# removed 'deep_hiv_ab_pred/catnap/constants.py'
# removed 'deep_hiv_ab_pred/catnap/dataset.py'
# removed 'deep_hiv_ab_pred/catnap/download_dataset.py'
# removed 'deep_hiv_ab_pred/catnap/__pycache__/__init__.cpython-38.pyc'
# removed 'deep_hiv_ab_pred/catnap/__pycache__/download_dataset.cpython-38.pyc'
# removed 'deep_hiv_ab_pred/catnap/__pycache__/constants.cpython-38.pyc'
# removed directory 'deep_hiv_ab_pred/catnap/__pycache__'
# removed 'deep_hiv_ab_pred/catnap/catnap_data/assay.text'
# removed 'deep_hiv_ab_pred/catnap/catnap_data/heavy_seqs_aa.fasta'
# removed 'deep_hiv_ab_pred/catnap/catnap_data/light_seqs_aa.fasta'
# removed 'deep_hiv_ab_pred/catnap/catnap_data/virseqs_aa.fasta'
# removed 'deep_hiv_ab_pred/catnap/catnap_data/virseqs_aa_O.fasta'
# removed 'deep_hiv_ab_pred/catnap/catnap_data/antibodies_details.text'
# removed directory 'deep_hiv_ab_pred/catnap/catnap_data'
# removed directory 'deep_hiv_ab_pred/catnap'
# removed 'deep_hiv_ab_pred/compare_to_Rawi_gbm/Rawi_data.json'
# removed 'deep_hiv_ab_pred/compare_to_Rawi_gbm/__init__.py'
# removed 'deep_hiv_ab_pred/compare_to_Rawi_gbm/constants.py'
# removed 'deep_hiv_ab_pred/compare_to_Rawi_gbm/create_splits.py'
# removed 'deep_hiv_ab_pred/compare_to_Rawi_gbm/models/__init__.py'
# removed directory 'deep_hiv_ab_pred/compare_to_Rawi_gbm/models'
# removed 'deep_hiv_ab_pred/compare_to_Rawi_gbm/parse_Rawi_data.py'
# removed 'deep_hiv_ab_pred/compare_to_Rawi_gbm/splits_Rawi_comparison.json'
# removed 'deep_hiv_ab_pred/compare_to_Rawi_gbm/statistics.py'
# removed 'deep_hiv_ab_pred/compare_to_Rawi_gbm/train_evaluate.py'
# removed directory 'deep_hiv_ab_pred/compare_to_Rawi_gbm/.ipynb_checkpoints'
# removed 'deep_hiv_ab_pred/compare_to_Rawi_gbm/__pycache__/__init__.cpython-38.pyc'
# removed 'deep_hiv_ab_pred/compare_to_Rawi_gbm/__pycache__/train_evaluate.cpython-38.pyc'
# removed 'deep_hiv_ab_pred/compare_to_Rawi_gbm/__pycache__/constants.cpython-38.pyc'
# removed directory 'deep_hiv_ab_pred/compare_to_Rawi_gbm/__pycache__'
# removed directory 'deep_hiv_ab_pred/compare_to_Rawi_gbm'
# removed 'deep_hiv_ab_pred/hyperparameters/__init__.py'
# removed 'deep_hiv_ab_pred/hyperparameters/constants.py'
# removed 'deep_hiv_ab_pred/hyperparameters/hyperparameters_iceri_2021.yml'
# removed 'deep_hiv_ab_pred/hyperparameters/__pycache__/__init__.cpython-38.pyc'
# removed 'deep_hiv_ab_pred/hyperparameters/__pycache__/constants.cpython-38.pyc'
# removed directory 'deep_hiv_ab_pred/hyperparameters/__pycache__'
# removed directory 'deep_hiv_ab_pred/hyperparameters'
# removed 'deep_hiv_ab_pred/model/ICERI2021.py'
# removed 'deep_hiv_ab_pred/model/__init__.py'
# removed 'deep_hiv_ab_pred/model/__pycache__/__init__.cpython-38.pyc'
# removed 'deep_hiv_ab_pred/model/__pycache__/ICERI2021.cpython-38.pyc'
# removed directory 'deep_hiv_ab_pred/model/__pycache__'
# removed directory 'deep_hiv_ab_pred/model'
# removed 'deep_hiv_ab_pred/plotting/__init__.py'
# removed 'deep_hiv_ab_pred/plotting/plotting.py'
# removed directory 'deep_hiv_ab_pred/plotting'
# removed 'deep_hiv_ab_pred/preprocessing/__init__.py'
# removed 'deep_hiv_ab_pred/preprocessing/constants.py'
# removed 'deep_hiv_ab_pred/preprocessing/pytorch_dataset.py'
# removed 'deep_hiv_ab_pred/preprocessing/sequences.py'
# removed 'deep_hiv_ab_pred/preprocessing/__pycache__/__init__.cpython-38.pyc'
# removed 'deep_hiv_ab_pred/preprocessing/__pycache__/pytorch_dataset.cpython-38.pyc'
# removed 'deep_hiv_ab_pred/preprocessing/__pycache__/sequences.cpython-38.pyc'
# removed 'deep_hiv_ab_pred/preprocessing/__pycache__/constants.cpython-38.pyc'
# removed directory 'deep_hiv_ab_pred/preprocessing/__pycache__'
# removed directory 'deep_hiv_ab_pred/preprocessing'
# removed 'deep_hiv_ab_pred/requirements.txt'
# removed 'deep_hiv_ab_pred/training/__init__.py'
# removed 'deep_hiv_ab_pred/training/constants.py'
# removed 'deep_hiv_ab_pred/training/training.py'
# removed 'deep_hiv_ab_pred/training/__pycache__/__init__.cpython-38.pyc'
# removed 'deep_hiv_ab_pred/training/__pycache__/training.cpython-38.pyc'
# removed 'deep_hiv_ab_pred/training/__pycache__/constants.cpython-38.pyc'
# removed directory 'deep_hiv_ab_pred/training/__pycache__'
# removed directory 'deep_hiv_ab_pred/training'
# removed 'deep_hiv_ab_pred/util/__init__.py'
# removed 'deep_hiv_ab_pred/util/tools.py'
# removed 'deep_hiv_ab_pred/util/__pycache__/__init__.cpython-38.pyc'
# removed 'deep_hiv_ab_pred/util/__pycache__/tools.cpython-38.pyc'
# removed directory 'deep_hiv_ab_pred/util/__pycache__'
# removed directory 'deep_hiv_ab_pred/util'
# removed 'deep_hiv_ab_pred/__pycache__/__init__.cpython-38.pyc'
# removed directory 'deep_hiv_ab_pred/__pycache__'
# removed directory 'deep_hiv_ab_pred'
# Cloning into 'deep_hiv_ab_pred'...
# remote: Enumerating objects: 217, done.
# remote: Counting objects: 100% (217/217), done.
# remote: Compressing objects: 100% (153/153), done.
# remote: Total 217 (delta 123), reused 150 (delta 62), pack-reused 0
# Receiving objects: 100% (217/217), 7.51 MiB | 9.89 MiB/s, done.
# Resolving deltas: 100% (123/123), done.

# %%
import sys
import os
sys.path.insert(0, 'deep_hiv_ab_pred')

# %%
from deep_hiv_ab_pred.catnap.download_dataset import download_catnap
from deep_hiv_ab_pred.compare_to_Rawi_gbm.train_evaluate import train_net

# %%
download_catnap()

# %%
tags = {
    'note1': 'virus seq aligned unlike in ICERI2021',
    'note2': 'no parameters are freezed'
}
train_net('ICERI2021', tags)
# Out:
# MlflowExceptionTraceback (most recent call last)
# <ipython-input-10-507dfbf5c327> in <module>
#       3     'note2': 'no parameters are freezed'
#       4 }
# ----> 5 train_net('ICERI2021', tags)
#
# /workspace/deep_hiv_ab_pred/compare_to_Rawi_gbm/train_evaluate.py in train_net(experiment, tags)
#      56
#      57 def train_net(experiment, tags = None):
# ---> 58     mlflow.create_experiment(experiment)
#      59     with mlflow.start_run(experiment_id = experiment, tags = tags):
#      60         conf = read_yaml(CONF_ICERI)
#
# /opt/conda/lib/python3.8/site-packages/mlflow/tracking/fluent.py in start_run(run_id, experiment_id, run_name, nested, tags)
#     248         tags = context_registry.resolve_tags(user_specified_tags)
#     249
# --> 250         active_run_obj = client.create_run(experiment_id=exp_id_for_run, tags=tags)
#     251
#     252     _active_run_stack.append(ActiveRun(active_run_obj))
#
# /opt/conda/lib/python3.8/site-packages/mlflow/tracking/client.py in create_run(self, experiment_id, start_time, tags)
#     263             status: RUNNING
#     264         """
# --> 265         return self._tracking_client.create_run(experiment_id, start_time, tags)
#     266
#     267     def list_run_infos(
#
# /opt/conda/lib/python3.8/site-packages/mlflow/tracking/_tracking_service/client.py in create_run(self, experiment_id, start_time, tags)
#      98         user_id = tags.get(MLFLOW_USER, "unknown")
#      99
# --> 100         return self.store.create_run(
#     101             experiment_id=experiment_id,
#     102             user_id=user_id,
#
# /opt/conda/lib/python3.8/site-packages/mlflow/store/tracking/file_store.py in create_run(self, experiment_id, user_id, start_time, tags)
#     480         """
#     481         experiment_id = FileStore.DEFAULT_EXPERIMENT_ID if experiment_id is None else experiment_id
# --> 482         experiment = self.get_experiment(experiment_id)
#     483         if experiment is None:
#     484             raise MlflowException(
#
# /opt/conda/lib/python3.8/site-packages/mlflow/store/tracking/file_store.py in get_experiment(self, experiment_id)
#     361         """
#     362         experiment_id = FileStore.DEFAULT_EXPERIMENT_ID if experiment_id is None else experiment_id
# --> 363         experiment = self._get_experiment(experiment_id)
#     364         if experiment is None:
#     365             raise MlflowException(
#
# /opt/conda/lib/python3.8/site-packages/mlflow/store/tracking/file_store.py in _get_experiment(self, experiment_id, view_type)
#     330         experiment_dir = self._get_experiment_path(experiment_id, view_type)
#     331         if experiment_dir is None:
# --> 332             raise MlflowException(
#     333                 "Could not find experiment with ID %s" % experiment_id,
#     334                 databricks_pb2.RESOURCE_DOES_NOT_EXIST,
#
# MlflowException: Could not find experiment with ID ICERI2021
